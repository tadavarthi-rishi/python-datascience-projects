# %%
import pandas as pd
dataset = pd.read_csv('UdemyCourses.csv')
dataset.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
dataset.isna().any()
# Out:
# course_id              False
# course_title           False
# is_paid                False
# price                  False
# num_subscribers        False
# num_reviews            False
# num_lectures           False
# level                  False
# content_duration       False
# published_timestamp    False
# subject                False
# dtype: bool

# %%
dataset.columns.tolist()
# Out:
# ['course_id',
#  'course_title',
#  'is_paid',
#  'price',
#  'num_subscribers',
#  'num_reviews',
#  'num_lectures',
#  'level',
#  'content_duration',
#  'published_timestamp',
#  'subject']

# %%
dataset.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %% [markdown]
# # Q1) what are all different subjects for which udemy is offering courses?

# %%
dataset.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # Q2) which subject has maximum number of courses?

# %%
dataset.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# # Q3) show all the courses which are free of cost?

# %%
dataset[dataset['is_paid']==False]['subject'].value_counts()
# Out:
# Web Development        133
# Business Finance        96
# Musical Instruments     46
# Graphic Design          35
# Name: subject, dtype: int64

# %%
dataset[dataset['is_paid']==False]['subject']
# Out:
# 41      Musical Instruments
# 49      Musical Instruments
# 57      Musical Instruments
# 67          Web Development
# 74         Business Finance
#                ...
# 3620        Web Development
# 3638        Web Development
# 3652        Web Development
# 3674    Musical Instruments
# 3680       Business Finance
# Name: subject, Length: 310, dtype: object

# %% [markdown]
# # Q4) show all the courses which are paid?

# %%
dataset[dataset.is_paid == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
dataset[dataset.is_paid == True]['subject']
# Out:
# 0       Musical Instruments
# 1       Musical Instruments
# 2       Musical Instruments
# 3       Musical Instruments
# 4       Musical Instruments
#                ...
# 3676       Business Finance
# 3677        Web Development
# 3678    Musical Instruments
# 3679        Web Development
# 3681         Graphic Design
# Name: subject, Length: 3372, dtype: object

# %%
dataset[dataset.is_paid == True]['subject'].value_counts()
# Out:
# Business Finance       1103
# Web Development        1067
# Musical Instruments     634
# Graphic Design          568
# Name: subject, dtype: int64

# %% [markdown]
# # Q5) which are top selling courses?

# %%
dataset.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
dataset.sort_values('num_subscribers',ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...     True
# 1267    1258666                Financial Statement Auditing Cycles     True
# 2070    1215926                Kickstarter success in 5 easy steps     True
# 1931    1247992  Introduction to Project Management for Finance...     True
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...     True
#
# ...

# %% [markdown]
# # Q6) which are the least selling courses?

# %%
dataset.sort_values('num_subscribers',ascending = True)
# Out:
#       course_id                                       course_title  is_paid  \
# 649     1233314                      Building a Balanced Scorecard     True
# 3259    1232282          The Cash Flow Statement - An Introduction     True
# 3261    1275872                    The Complete Adobe Spark Course     True
# 910      726314       Create Beautiful Image Maps for Your Website     True
# 3328     715476        The Cuckoo Strategy to get European Funding     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %% [markdown]
# # Q7) show all the courses of graphics design where the price is below 100?

# %%
dataset.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
a=dataset.groupby('subject').get_group('Graphic Design')

# %%
dataset.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
dataset['price'].replace('Free',0,inplace = True)

# %%
dataset['price'].dtypes
# Out:
# dtype('O')

# %%
dataset['price']= pd.to_numeric(dataset['price'])

# %%
dataset.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                   int64
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
dataset.groupby('subject').get_group('Graphic Design')[dataset['price']<100]
# Out:
# /var/folders/ll/s3zfpkx15gn379_sccsln_6m0000gn/T/ipykernel_4066/2634715699.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset.groupby('subject').get_group('Graphic Design')[dataset['price']<100]
#       course_id                                       course_title  is_paid  \
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20      1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35      1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39       599652                     48 Logo Designs and Techniques     True
# 52       794036       8 Stunden professionelles Cinema 4D Training     True
# ...         ...                                                ...      ...
# 3568     133968                 Web Elements Design With Photoshop     True
# 3588    1131780  Whiteboard Animation, Beginner To Expert - In ...     True
# ...

# %% [markdown]
# # or another method

# %%
dataset[(dataset.subject == 'Graphic Design') & (dataset.price < 100)].sort_values(by='price')
# Out:
#       course_id                                       course_title  is_paid  \
# 175      723818                        Adobe Indesign CC Başlangıç    False
# 836      902300       Convert Image to Vector in Adobe illustrator    False
# 319      896742             Aprenda Modelagem 3D com o 123D Design    False
# 161      733878  Adobe Illustrator Course in Urdu Basics Level ...    False
# 2157    1260674  Learn Comic Book Color Flatting! (Coloring Ass...    False
# ...         ...                                                ...      ...
# 1470     396204  Graphic Design Masterclass: Learn Graphic Desi...     True
# 1298     834226                     FLAT ICON DESIGN IN POWERPOINT     True
# 1033     805882  Design bestselling T-shirts from Beginner to E...     True
# 1783    1197206                         Illustrator CC MasterClass     True
# 1214     857144                      FACEBOOK COVERS IN POWERPOINT     True
#
# ...

# %%
dataset[(dataset.subject == 'Graphic Design') & (dataset.price < 100)].sort_values(by='price',ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2873    1126016  Portrait Typography in Photoshop - Anyone can ...     True
# 1470     396204  Graphic Design Masterclass: Learn Graphic Desi...     True
# 2622     787204  Most Wanted Flat Design Techniques #2: Hipster...     True
# 2623     787096  Most Wanted Flat Design Techniques #3: Office ...     True
# 2500     286160  Making Killer Images in Photoshop that WOW Cli...     True
# ...         ...                                                ...      ...
# 1056     901082  Digital Art in Adobe Illustrator CC: Angry Bir...    False
# 2157    1260674  Learn Comic Book Color Flatting! (Coloring Ass...    False
# 319      896742             Aprenda Modelagem 3D com o 123D Design    False
# 2231     627782  Learn Illustrator By Recreating Top 3 Logos - ...    False
# 384     1249378  AutoCAD Course - Learn Online AutoCAD in Urdu ...    False
#
# ...

# %% [markdown]
# # Q8) list out all the courses that are related with 'python'

# %%
dataset.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments

# %%
dataset[dataset.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
len(dataset[dataset.course_title.str.contains('Python')])
# Out:
# 29

# %% [markdown]
# # Q9) what are the courses that are published in 2015?

# %%
dataset.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments

# %%
dataset['published_timestamp'] = pd.to_datetime(dataset['published_timestamp'])

# %%
dataset[dataset['published_timestamp'].dt.year == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
len(dataset[dataset['published_timestamp'].dt.year == 2015])
# Out:
# 1014

# %%
dataset[dataset['published_timestamp'].dt.year == 2015]['course_title'].unique()
# Out:
# array(['1 - Concepts of Statistics For Beginners Step by Step',
#        '10 Numbers Every Business Owner Should Know',
#        '101 Blues riffs - learn how the harmonica superstars do it', ...,
#        'Your Own Site in 45 Min: The Complete Wordpress Course',
#        'Your Second Course on Piano: Two Handed Playing',
#        'Zend Framework 2: Learn the PHP framework ZF2 from scratch'],
#       dtype=object)

# %%
dataset[dataset['published_timestamp'].dt.year == 2015]['course_title'].unique().tolist()
# Out:
# ['1 - Concepts of Statistics For Beginners Step by Step',
#  '10 Numbers Every Business Owner Should Know',
#  '101 Blues riffs - learn how the harmonica superstars do it',
#  '16 Guitar Chords to Jam With - (Beginner - Intermediate)',
#  '2 Easy Steps To Investment And Avoiding Traps',
#  '3 step formula for playing guitar by ear',
#  '31 Day Guitar Challenge',
#  '3D Programming with WebGL and Babylon.js for Beginners',
#  '48 Logo Designs and Techniques',
#  '6 Must Know Tricks to Successful Solos',
#  '7 Deadly Mistakes of Investing that Will Slash Your Profits!',
#  '7 Ways A Beginner Guitarist Can Sound Better, Instantly!',
#  '8 Steps To Achieve Financial Freedom And Escape Debt',
#  '88 Logic - The Essential Guide To Learning Piano',
#  'A Beginners Guide to creating Vector Graphics With Photoshop',
#  'A Complete Guide to Successful Freelance Logo Design Career',
#  'A Value Investing Approach to the Stock Market',
#  'สอนเทรดไบนารี่ อ๊อฟชั่นอย่างง่าย',
# ...

# %%
len(dataset[dataset['published_timestamp'].dt.year == 2015]['course_title'].unique().tolist())
# Out:
# 1014

# %% [markdown]
# # Q10) what is the max number of subscribers for each level of courses?

# %%
dataset.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments
# 2        1.5 hours 2017-04-26 18:34:57+00:00  Musical Instruments

# %%
dataset.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
dataset.groupby('level')['num_subscribers'].value_counts()
# Out:
# level               num_subscribers
# All Levels          0                  25
#                     1                  16
#                     7                  14
#                     4                  13
#                     3                  11
#                                        ..
# Intermediate Level  16282               1
#                     18777               1
#                     21998               1
#                     25799               1
#                     29167               1
# Name: num_subscribers, Length: 2709, dtype: int64

# %%
dataset.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid  price  num_subscribers  num_reviews  \
# level
# All Levels             True    200           268923        27445
# Beginner Level         True    200           161029         5924
# Expert Level           True    200             5172          249
# Intermediate Level     True    200            29167         3326
#
#                     num_lectures content_duration       published_timestamp  \
# level
# ...
