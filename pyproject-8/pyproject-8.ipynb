# %%
import pandas as pd
dataset = pd.read_csv('NetflixDataset.csv')
dataset.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
dataset.shape
# Out:
# (7789, 11)

# %%
dataset.isna().any()
# Out:
# Show_Id         False
# Category        False
# Title           False
# Director         True
# Cast             True
# Country          True
# Release_Date     True
# Rating           True
# Duration        False
# Type            False
# Description     False
# dtype: bool

# %%
dataset.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
dataset.duplicated().value_counts()
# Out:
# False    7787
# True        2
# dtype: int64

# %%
dataset.size
#shows total no of values in dataset
# Out:
# 85679

# %%
dataset.columns.tolist()
# Out:
# ['Show_Id',
#  'Category',
#  'Title',
#  'Director',
#  'Cast',
#  'Country',
#  'Release_Date',
#  'Rating',
#  'Duration',
#  'Type',
#  'Description']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Task.1 is there any duplicate values or records in dataset?
# if yes remove the duplicate records

# %%
dataset.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
dataset[dataset.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
dataset.drop_duplicates(inplace = True)
#removes the duplicate rows or records permanently

# %%
# now check if the duplicated records are removed or not
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
dataset.shape
# Out:
# (7787, 11)

# %% [markdown]
# # Task.2 check if there are any null values present
# if yes show with heat map

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(dataset.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q1) for 'house of cards' what is the show id and who is tthe director of this show?

# %%
dataset.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
dataset[dataset['Title'] == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
dataset[dataset['Title'] == 'House of Cards'].Show_Id
# Out:
# 2832    s2833
# Name: Show_Id, dtype: object

# %%
dataset[dataset['Title'] == 'House of Cards'].Director.tolist()
# Out:
# ['Robin Wright, David Fincher, Gerald McRaney, John David Coles, David Manson']

# %%
# another method

# %%
dataset[dataset['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Q2) in which year highest number of the TV shows & Movies were released ? show with bar graph

# %%
dataset['Release_Date'] = pd.to_datetime(dataset['Release_Date'])

# %%
dataset[dataset['Category'] == ('TV Show' or 'Movies')]['Release_Date'].dt.year.value_counts()
# Out:
# 2020.0    697
# 2019.0    656
# 2018.0    430
# 2017.0    361
# 2016.0    185
# 2015.0     30
# 2021.0     29
# 2014.0      6
# 2013.0      5
# 2008.0      1
# Name: Release_Date, dtype: int64

# %%
dataset[dataset['Category'] == ('TV Show' or 'Movies')]['Release_Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q3) how many movies and TV shows are in dataset? show in bar graph

# %%
dataset.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
dataset.groupby('Category').Category.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# # countplot()

# %%
sns.countplot(dataset.Category)
# Out:
# /Users/rishisathwik/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# # Q4) show all the movies that were released in year 2000

# %%
dataset.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# ...

# %%
dataset[(dataset.Category == 'Movie') & (dataset['Release_Date'].dt.year==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
len(dataset[(dataset.Category == 'Movie') & (dataset['Release_Date'].dt.year==2020)])
# Out:
# 1312

# %% [markdown]
# # Q5) show only the Titles of all TV shows that were released in india only.

# %%
dataset.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# ...

# %%
dataset[(dataset['Category'] == 'TV Show') & (dataset['Country']=='India')]['Title'].tolist()
# Out:
# ['21 Sarfarosh: Saragarhi 1897',
#  '7 (Seven)',
#  'Agent Raghav',
#  'Akbar\xa0Birbal',
#  'Anjaan: Rural Myths',
#  'Anjaan: Special Crimes Unit',
#  'Bad Boy Billionaires: India',
#  'Badalte Rishton Ki Dastaan',
#  'Bard of Blood',
#  'Betaal',
#  'Bh Se Bhade',
#  'Bhaag Beanie Bhaag',
#  'Bhaage Re Mann',
#  'Chhota Bheem',
#  'ChuChu TV Nursery Rhymes & Kids Songs (Hindi)',
#  'Classic Legends',
#  'College Romance',
#  'Cricket Fever: Mumbai Indians',
#  'Darr Sabko Lagta Hai',
#  'Delhi Crime',
#  'Devlok with Devdutt Pattanaik',
#  'Dharmakshetra',
#  'Engineering Girls',
#  'Fabulous Lives of Bollywood Wives',
#  'Fear Files... Har Mod Pe Darr',
#  'Gabru: Hip Hop Revolution',
#  'Gangs of Hassepur',
#  'GHOUL',
#  'Girls Hostel',
#  'Hasmukh',
#  'Inmates',
#  'Jamtara - Sabka Number Ayega',
#  'Jhansi Ki Rani',
#  'Khan: No. 1 Crime Hunter',
#  'Khelti Hai Zindagi Aankh Micholi',
#  'Khotey Sikkey',
#  'Ladies Up',
#  'Leila',
#  'Little Singham',
#  'Little Things',
# ...

# %% [markdown]
# # Q6)Show top 10 directors who gave the highest number of TV shows and movies to netflix?

# %%
dataset['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# # Q7) show all the records, where 'category is movie and type is comedies' or 'country is United Kingdom'.

# %%
dataset[(dataset['Category']=='Movie') & (dataset['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
dataset[(dataset['Category']=='Movie') & (dataset['Type'] == 'Comedies') | (dataset['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # Q8) in how many movies/shows, tom cruise was cast?

# %%
dataset[dataset['Cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
dataset[dataset['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ll/s3zfpkx15gn379_sccsln_6m0000gn/T/ipykernel_76383/3143192519.py in <module>
# ----> 1 dataset[dataset['Cast'].str.contains('Tom Cruise')]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
# -> 3495         if com.is_bool_indexer(key):
#    3496             return self._getitem_bool_array(key)
#    3497
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     142                     # Don't raise on e.g. ["A", "B", np.nan], see
#     143                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 144                     raise ValueError(na_msg)
#     145                 return False
#     146             return True
#
# ...

# %% [markdown]
# # create a new dataframe by removing nan values

# %%
dataset_new = dataset.dropna()

# %%
dataset_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %%
dataset_new[dataset_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# # Q9) what are different ratings defined by Netflix?

# %%
dataset['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
dataset['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# # Q9.1) how many movies got the 'TV-14' rating in canada?

# %%
dataset[(dataset['Rating'] == 'TV-14') & (dataset['Country'] == 'Canada')&(dataset['Category']=='Movie')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
len(dataset[(dataset['Rating'] == 'TV-14') & (dataset['Country'] == 'Canada')&(dataset['Category']=='Movie')])
# Out:
# 11

# %% [markdown]
# # Q 9.2) how many TV shows got the 'R' rating after year 2018?

# %%
dataset_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...

# %%
dataset[(dataset['Rating']=='R')&(dataset['Release_Date'].dt.year > 2018)&(dataset['Category']=='TV Show')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description
# 6437  Trapped at a stagecoach stop as a storm rages ...

# %% [markdown]
# # Q 10) what is the maximum duration of a Movie/show on netflix?

# %%
dataset.Duration.sort_values(ascending = False)
# Out:
# 2103      99 min
# 2078      99 min
# 3424      99 min
# 3224      99 min
# 5421      99 min
#           ...
# 1933    1 Season
# 868     1 Season
# 4431    1 Season
# 869     1 Season
# 724     1 Season
# Name: Duration, Length: 7787, dtype: object

# %%
dataset.Duration.max()
# Out:
# '99 min'

# %% [markdown]
# # Q 11) which individual country has the highest no of TV shoes?

# %%
dataset.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# ...

# %%
dataset[dataset['Category']=='TV Show']['Country'].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# # Q12) how can we sort the dataset by year?

# %%
dataset['Year'] = dataset.Release_Date.dt.year

# %%
dataset.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description    Year
# 0  In a future where the elite inhabit an island ...  2020.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
dataset.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
dataset.sort_values(by = 'Year', ascending = False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %% [markdown]
# # Q13) find all the instances where category is 'Movie' and type is 'Drama' or category os 'TV Show' and type is 'Kids tv'

# %%
dataset[((dataset['Category']=='Movie')&(dataset['Type']=='Dramas'))|((dataset['Category']=='TV Show')&(dataset['Type']=='Kids TV'))]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
